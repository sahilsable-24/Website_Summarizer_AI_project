# %%
from scrapper import fetch_website_content
from openai import OpenAI
from IPython.display import Markdown,display

# %%
ollama_url = "http://localhost:11434/v1"
model = "llama3.2:1b"

# %%
system_prompt = """
You are a an assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
def summarize(url):
    ollama = OpenAI(base_url=ollama_url, api_key='ollama')
    website = fetch_website_content(url)
    response = ollama.chat.completions.create(model=model,
                                              messages=[
                                                  {"role":"system", "content":system_prompt},
                                                  {"role":"user", "content":user_prompt_prefix + website}])
    summary = response.choices[0].message.content
    return summary

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://sahilsable-24.github.io/portfolio/")
# Out:
# # Massively by HTML5 UP: A Wee Bit of AI Magic Happens Here
#
# This website claims to be about "Massively" (hence the name) data science insights delivered in a "HTML5 UP"-powered package. It features contributions from Sahil Sable, a Data Scientist & Analyst known for his machine learning skills.
#
# The site projects an enthusiasm for building solutions using Python and Tableau that can tackle real-world problems. Here's a brief rundown of each project:
#
# * Absenteeim: An analysis of employee absenteeism data to predict upcoming absences.
# * Prediction: A machine learning-based model aimed at predicting audiobook sales with TensorFlow.
# * Google Trends: Analysis of Google search trends correlating with Bitcoin and US economic indicators to uncover market shifts.
# * MNIST: Deep learning classification on images of handwritten digits from the infamous MNIST dataset, providing a hands-on guide for beginners.
#
# The projects are designed with reusability in mind, leveraging the strength of separate components. Overall, it's a website that showcases various data science techniques and projects, promising something productive and insightful to visitors.
